# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexdatser/dosronbek-AI-application-/blob/main/week7_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)

# %%
import requests
# Save datagenerators as file to colab working directory
# If you are using GitHub, make sure you get the "Raw" version of the code
url = 'https://raw.githubusercontent.com/NVDLI/LDL/main/pt_framework/utilities.py'
r = requests.get(url)

# make sure your filename is the same as how you want to import 
with open('utilities.py', 'w') as f:
    f.write(r.text)

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader
import numpy as np
from utilities import train_model

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
EPOCHS = 128
BATCH_SIZE = 32

# Load training dataset into a single batch to compute mean and stddev.
transform = transforms.Compose([transforms.ToTensor()])
trainset = CIFAR10(root='./pt_data', train=True, download=True, transform=transform)
trainloader = DataLoader(trainset, batch_size=len(trainset), shuffle=False)
data = next(iter(trainloader))
mean = data[0].mean()
stddev = data[0].std()

# Load and standardize training and test dataset.
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize(mean, stddev)])

trainset = CIFAR10(root='./pt_data', train=True, download=True, transform=transform)
testset = CIFAR10(root='./pt_data', train=False, download=True, transform=transform)

# Model with 2 convolutional and 1 fully-connected layer.
model = nn.Sequential(
    nn.Conv2d(3, 64, 5, stride=2, padding=2), # Output is 64x16x16.
    nn.ReLU(),
    nn.Conv2d(64, 64, 3, stride=2, padding=1), # Output is 64x8x8.
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(64 * 8 * 8, 10)
)

# Retrieve layers for custom weight initialization.
layers = next(model.modules())
conv_layer0 = layers[0]
conv_layer1 = layers[2]
output_layer = layers[5]

# Kaiming (He) initialization.
nn.init.kaiming_normal_(conv_layer0.weight)
nn.init.constant_(conv_layer0.bias, 0.0)
nn.init.kaiming_normal_(conv_layer1.weight)
nn.init.constant_(conv_layer1.bias, 0.0)

# Xavier (Glorot) initialization.
nn.init.xavier_uniform_(output_layer.weight)
nn.init.constant_(output_layer.bias, 0.0)

# Loss function and optimizer
optimizer = torch.optim.Adam(model.parameters())
loss_function = nn.CrossEntropyLoss()

# Train the model.
train_model(model, device, EPOCHS, BATCH_SIZE, trainset, testset,
            optimizer, loss_function, 'acc')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./pt_data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./pt_data/cifar-10-python.tar.gz to ./pt_data
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/128 loss: 1.4023 - acc: 0.5050 - val_loss: 1.1915 - val_acc: 0.5753
# Epoch 2/128 loss: 1.0502 - acc: 0.6355 - val_loss: 1.0640 - val_acc: 0.6327
# Epoch 3/128 loss: 0.9060 - acc: 0.6848 - val_loss: 1.0280 - val_acc: 0.6483
# Epoch 4/128 loss: 0.8062 - acc: 0.7207 - val_loss: 1.0314 - val_acc: 0.6543
# Epoch 5/128 loss: 0.7308 - acc: 0.7455 - val_loss: 1.0577 - val_acc: 0.6512
# Epoch 6/128 loss: 0.6684 - acc: 0.7685 - val_loss: 1.0799 - val_acc: 0.6562
# Epoch 7/128 loss: 0.6044 - acc: 0.7882 - val_loss: 1.1509 - val_acc: 0.6493
# Epoch 8/128 loss: 0.5498 - acc: 0.8075 - val_loss: 1.1554 - val_acc: 0.6501
# Epoch 9/128 loss: 0.5049 - acc: 0.8200 - val_loss: 1.2172 - val_acc: 0.6501
# Epoch 10/128 loss: 0.4637 - acc: 0.8356 - val_loss: 1.3265 - val_acc: 0.6368
# Epoch 11/128 loss: 0.4271 - acc: 0.8500 - val_loss: 1.4005 - val_acc: 0.6394
# Epoch 12/128 loss: 0.3909 - acc: 0.8603 - val_loss: 1.4812 - val_acc: 0.6348
# Epoch 13/128 loss: 0.3589 - acc: 0.8714 - val_loss: 1.6348 - val_acc: 0.6285
# Epoch 14/128 loss: 0.3363 - acc: 0.8805 - val_loss: 1.6883 - val_acc: 0.6317
# Epoch 15/128 loss: 0.3121 - acc: 0.8862 - val_loss: 1.7580 - val_acc: 0.6307
# Epoch 16/128 loss: 0.2891 - acc: 0.8963 - val_loss: 1.8576 - val_acc: 0.6289
# Epoch 17/128 loss: 0.2736 - acc: 0.9010 - val_loss: 1.9427 - val_acc: 0.6238
# Epoch 18/128 loss: 0.2490 - acc: 0.9108 - val_loss: 2.0896 - val_acc: 0.6256
# Epoch 19/128 loss: 0.2437 - acc: 0.9116 - val_loss: 2.1530 - val_acc: 0.6235
# Epoch 20/128 loss: 0.2290 - acc: 0.9169 - val_loss: 2.2507 - val_acc: 0.6252
# Epoch 21/128 loss: 0.2148 - acc: 0.9232 - val_loss: 2.3799 - val_acc: 0.6228
# Epoch 22/128 loss: 0.2124 - acc: 0.9248 - val_loss: 2.4649 - val_acc: 0.6220
# Epoch 23/128 loss: 0.1920 - acc: 0.9293 - val_loss: 2.6135 - val_acc: 0.6213
# Epoch 24/128 loss: 0.1963 - acc: 0.9291 - val_loss: 2.6368 - val_acc: 0.6142
# Epoch 25/128 loss: 0.1840 - acc: 0.9333 - val_loss: 2.7512 - val_acc: 0.6185
# Epoch 26/128 loss: 0.1772 - acc: 0.9358 - val_loss: 2.9248 - val_acc: 0.6206
# Epoch 27/128 loss: 0.1753 - acc: 0.9372 - val_loss: 2.9867 - val_acc: 0.6131
# Epoch 28/128 loss: 0.1672 - acc: 0.9410 - val_loss: 3.0626 - val_acc: 0.6217
# Epoch 29/128 loss: 0.1674 - acc: 0.9413 - val_loss: 3.1558 - val_acc: 0.6200
# Epoch 30/128 loss: 0.1539 - acc: 0.9457 - val_loss: 3.3309 - val_acc: 0.6156
# Epoch 31/128 loss: 0.1613 - acc: 0.9432 - val_loss: 3.3923 - val_acc: 0.6129
# Epoch 32/128 loss: 0.1560 - acc: 0.9466 - val_loss: 3.3892 - val_acc: 0.6169
# Epoch 33/128 loss: 0.1517 - acc: 0.9457 - val_loss: 3.6137 - val_acc: 0.6090
# Epoch 34/128 loss: 0.1459 - acc: 0.9491 - val_loss: 3.6450 - val_acc: 0.6136
# Epoch 35/128 loss: 0.1427 - acc: 0.9515 - val_loss: 3.6943 - val_acc: 0.6190
# Epoch 36/128 loss: 0.1421 - acc: 0.9506 - val_loss: 3.7927 - val_acc: 0.6131
# Epoch 37/128 loss: 0.1506 - acc: 0.9503 - val_loss: 3.9057 - val_acc: 0.6140
# Epoch 38/128 loss: 0.1439 - acc: 0.9533 - val_loss: 4.0569 - val_acc: 0.6137
# Epoch 39/128 loss: 0.1410 - acc: 0.9532 - val_loss: 4.1118 - val_acc: 0.6156
# Epoch 40/128 loss: 0.1435 - acc: 0.9524 - val_loss: 4.2568 - val_acc: 0.6158
# Epoch 41/128 loss: 0.1422 - acc: 0.9528 - val_loss: 4.3138 - val_acc: 0.6205
# Epoch 42/128 loss: 0.1372 - acc: 0.9548 - val_loss: 4.4063 - val_acc: 0.6163
# Epoch 43/128 loss: 0.1351 - acc: 0.9556 - val_loss: 4.4848 - val_acc: 0.6147
# Epoch 44/128 loss: 0.1389 - acc: 0.9561 - val_loss: 4.5839 - val_acc: 0.6146
# Epoch 45/128 loss: 0.1361 - acc: 0.9552 - val_loss: 4.7877 - val_acc: 0.6094
# Epoch 46/128 loss: 0.1340 - acc: 0.9574 - val_loss: 4.7147 - val_acc: 0.6184
# Epoch 47/128 loss: 0.1273 - acc: 0.9595 - val_loss: 4.8409 - val_acc: 0.6130
# Epoch 48/128 loss: 0.1405 - acc: 0.9564 - val_loss: 4.8371 - val_acc: 0.6153
# Epoch 49/128 loss: 0.1335 - acc: 0.9597 - val_loss: 5.0208 - val_acc: 0.6180
# Epoch 50/128 loss: 0.1346 - acc: 0.9591 - val_loss: 5.0494 - val_acc: 0.6085
# Epoch 51/128 loss: 0.1365 - acc: 0.9586 - val_loss: 5.1236 - val_acc: 0.6099
# Epoch 52/128 loss: 0.1297 - acc: 0.9599 - val_loss: 5.2219 - val_acc: 0.6163
# Epoch 53/128 loss: 0.1297 - acc: 0.9610 - val_loss: 5.4670 - val_acc: 0.6079
# Epoch 54/128 loss: 0.1311 - acc: 0.9606 - val_loss: 5.3121 - val_acc: 0.6191
# Epoch 55/128 loss: 0.1437 - acc: 0.9589 - val_loss: 5.6411 - val_acc: 0.6175
# Epoch 56/128 loss: 0.1313 - acc: 0.9608 - val_loss: 5.5688 - val_acc: 0.6192
# Epoch 57/128 loss: 0.1313 - acc: 0.9616 - val_loss: 5.6615 - val_acc: 0.6130
# Epoch 58/128 loss: 0.1456 - acc: 0.9595 - val_loss: 5.8084 - val_acc: 0.6129
# Epoch 59/128 loss: 0.1288 - acc: 0.9637 - val_loss: 5.9182 - val_acc: 0.6074
# Epoch 60/128 loss: 0.1256 - acc: 0.9634 - val_loss: 6.0526 - val_acc: 0.6116
# Epoch 61/128 loss: 0.1220 - acc: 0.9632 - val_loss: 6.2405 - val_acc: 0.6103
# Epoch 62/128 loss: 0.1400 - acc: 0.9616 - val_loss: 6.2422 - val_acc: 0.6127
# Epoch 63/128 loss: 0.1355 - acc: 0.9620 - val_loss: 6.2345 - val_acc: 0.6135
# Epoch 64/128 loss: 0.1239 - acc: 0.9651 - val_loss: 6.3434 - val_acc: 0.6142
# Epoch 65/128 loss: 0.1336 - acc: 0.9642 - val_loss: 6.5848 - val_acc: 0.6163
# Epoch 66/128 loss: 0.1262 - acc: 0.9656 - val_loss: 6.5487 - val_acc: 0.6096
# Epoch 67/128 loss: 0.1324 - acc: 0.9651 - val_loss: 6.6263 - val_acc: 0.6140
# Epoch 68/128 loss: 0.1393 - acc: 0.9645 - val_loss: 6.8298 - val_acc: 0.6106
# Epoch 69/128 loss: 0.1318 - acc: 0.9654 - val_loss: 6.7977 - val_acc: 0.6083
# Epoch 70/128 loss: 0.1249 - acc: 0.9669 - val_loss: 6.9741 - val_acc: 0.6140
# Epoch 71/128 loss: 0.1320 - acc: 0.9655 - val_loss: 7.2760 - val_acc: 0.6082
# Epoch 72/128 loss: 0.1343 - acc: 0.9663 - val_loss: 7.1746 - val_acc: 0.6045
# Epoch 73/128 loss: 0.1310 - acc: 0.9667 - val_loss: 7.0963 - val_acc: 0.6091
# Epoch 74/128 loss: 0.1352 - acc: 0.9660 - val_loss: 7.4364 - val_acc: 0.6151
# Epoch 75/128 loss: 0.1232 - acc: 0.9682 - val_loss: 7.3219 - val_acc: 0.6084
# Epoch 76/128 loss: 0.1460 - acc: 0.9649 - val_loss: 7.3545 - val_acc: 0.6130
# Epoch 77/128 loss: 0.1324 - acc: 0.9674 - val_loss: 7.5026 - val_acc: 0.6067
# Epoch 78/128 loss: 0.1199 - acc: 0.9692 - val_loss: 7.6847 - val_acc: 0.6074
# Epoch 79/128 loss: 0.1300 - acc: 0.9672 - val_loss: 7.7452 - val_acc: 0.6139
# Epoch 80/128 loss: 0.1281 - acc: 0.9681 - val_loss: 7.7838 - val_acc: 0.6128
# Epoch 81/128 loss: 0.1282 - acc: 0.9685 - val_loss: 8.0072 - val_acc: 0.6083
# Epoch 82/128 loss: 0.1361 - acc: 0.9685 - val_loss: 8.0221 - val_acc: 0.6120
# Epoch 83/128 loss: 0.1250 - acc: 0.9699 - val_loss: 8.0481 - val_acc: 0.6085
# Epoch 84/128 loss: 0.1325 - acc: 0.9682 - val_loss: 8.0211 - val_acc: 0.6066
# Epoch 85/128 loss: 0.1414 - acc: 0.9677 - val_loss: 8.0904 - val_acc: 0.6109
# Epoch 86/128 loss: 0.1352 - acc: 0.9688 - val_loss: 8.5111 - val_acc: 0.6105
# Epoch 87/128 loss: 0.1302 - acc: 0.9697 - val_loss: 8.4263 - val_acc: 0.6119
# Epoch 88/128 loss: 0.1294 - acc: 0.9702 - val_loss: 8.6000 - val_acc: 0.6071
# Epoch 89/128 loss: 0.1477 - acc: 0.9672 - val_loss: 8.8746 - val_acc: 0.6080
# Epoch 90/128 loss: 0.1269 - acc: 0.9708 - val_loss: 8.8770 - val_acc: 0.6086
# Epoch 91/128 loss: 0.1316 - acc: 0.9701 - val_loss: 8.9061 - val_acc: 0.6059
# Epoch 92/128 loss: 0.1366 - acc: 0.9703 - val_loss: 9.2652 - val_acc: 0.6068
# Epoch 93/128 loss: 0.1217 - acc: 0.9725 - val_loss: 9.0350 - val_acc: 0.6109
# Epoch 94/128 loss: 0.1469 - acc: 0.9692 - val_loss: 9.3906 - val_acc: 0.6080
# Epoch 95/128 loss: 0.1344 - acc: 0.9708 - val_loss: 9.3283 - val_acc: 0.6076
# Epoch 96/128 loss: 0.1339 - acc: 0.9713 - val_loss: 9.3954 - val_acc: 0.6120
# Epoch 97/128 loss: 0.1252 - acc: 0.9729 - val_loss: 9.5542 - val_acc: 0.6082
# Epoch 98/128 loss: 0.1366 - acc: 0.9706 - val_loss: 9.6144 - val_acc: 0.6085
# Epoch 99/128 loss: 0.1281 - acc: 0.9723 - val_loss: 9.8323 - val_acc: 0.5985
# Epoch 100/128 loss: 0.1445 - acc: 0.9713 - val_loss: 9.6991 - val_acc: 0.6116
# Epoch 101/128 loss: 0.1456 - acc: 0.9711 - val_loss: 10.2362 - val_acc: 0.6090
# Epoch 102/128 loss: 0.1355 - acc: 0.9724 - val_loss: 10.2354 - val_acc: 0.6075
# Epoch 103/128 loss: 0.1331 - acc: 0.9724 - val_loss: 10.0340 - val_acc: 0.6105
# Epoch 104/128 loss: 0.1343 - acc: 0.9728 - val_loss: 10.2205 - val_acc: 0.6095
# Epoch 105/128 loss: 0.1322 - acc: 0.9730 - val_loss: 10.3015 - val_acc: 0.6098
# Epoch 106/128 loss: 0.1541 - acc: 0.9701 - val_loss: 10.4748 - val_acc: 0.6127
# Epoch 107/128 loss: 0.1345 - acc: 0.9731 - val_loss: 10.7872 - val_acc: 0.6142
# Epoch 108/128 loss: 0.1486 - acc: 0.9714 - val_loss: 10.5669 - val_acc: 0.6103
# Epoch 109/128 loss: 0.1392 - acc: 0.9729 - val_loss: 10.9082 - val_acc: 0.6049
# Epoch 110/128 loss: 0.1314 - acc: 0.9743 - val_loss: 11.1402 - val_acc: 0.6022
# Epoch 111/128 loss: 0.1408 - acc: 0.9738 - val_loss: 10.9612 - val_acc: 0.6110
# Epoch 112/128 loss: 0.1268 - acc: 0.9755 - val_loss: 11.1262 - val_acc: 0.6100
# Epoch 113/128 loss: 0.1455 - acc: 0.9731 - val_loss: 11.1635 - val_acc: 0.6076
# Epoch 114/128 loss: 0.1395 - acc: 0.9735 - val_loss: 11.3694 - val_acc: 0.6065
# Epoch 115/128 loss: 0.1259 - acc: 0.9751 - val_loss: 11.4950 - val_acc: 0.6063
# Epoch 116/128 loss: 0.1436 - acc: 0.9731 - val_loss: 11.3346 - val_acc: 0.6110
# Epoch 117/128 loss: 0.1302 - acc: 0.9755 - val_loss: 11.5908 - val_acc: 0.6118
# Epoch 118/128 loss: 0.1376 - acc: 0.9753 - val_loss: 11.9039 - val_acc: 0.6051
# Epoch 119/128 loss: 0.1408 - acc: 0.9750 - val_loss: 12.0348 - val_acc: 0.6136
# Epoch 120/128 loss: 0.1405 - acc: 0.9737 - val_loss: 12.1363 - val_acc: 0.6019
# Epoch 121/128 loss: 0.1410 - acc: 0.9746 - val_loss: 11.8355 - val_acc: 0.6052
# Epoch 122/128 loss: 0.1374 - acc: 0.9755 - val_loss: 12.0474 - val_acc: 0.6147
# Epoch 123/128 loss: 0.1274 - acc: 0.9760 - val_loss: 12.1871 - val_acc: 0.6049
# Epoch 124/128 loss: 0.1530 - acc: 0.9736 - val_loss: 12.4536 - val_acc: 0.6070
# Epoch 125/128 loss: 0.1243 - acc: 0.9769 - val_loss: 12.6755 - val_acc: 0.6076
# Epoch 126/128 loss: 0.1448 - acc: 0.9749 - val_loss: 12.6907 - val_acc: 0.6079
# Epoch 127/128 loss: 0.1379 - acc: 0.9762 - val_loss: 12.9274 - val_acc: 0.6136
# Epoch 128/128 loss: 0.1518 - acc: 0.9740 - val_loss: 12.7537 - val_acc: 0.6054
# [0.9740083173384517, 0.6054313099041534]
